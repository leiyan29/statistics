# %% [markdown]
# # Random sampling
#
# ### Some definitions
#
# 1. stratified sampling: random samples based on stratas, i.e. splitting population by age groups and randomly pulling samples from each strata
#
# 2. sample biais: a sample misrepresenting the population, i.e. polling one city when you want to understand the political leanings of the entire country
#
# 3. data snooping: find something inteAresting in data without looking through all of your data before modeling
#
# 4. vast search effect: to find outliers
#
# 5. data distribution: frequency distribution of individual values in a dataset
#
# 6. central limit theorem: the means drawn from multiple samples from data ressemble a bell-shaped normal curve
#
# data source: https://www.kaggle.com/competitions/nfl-big-data-bowl-2022/data?select=players.csv

# %%
import pandas as pd 

player_data_import = pd.read_csv('./data/players.csv')
player_data_import
# Out:
#       nflId height  weight   birthDate          collegeName Position  \
# 0     42901    6-1     208  1992-07-25        James Madison       SS
# 1     43501    6-0     220  1994-08-11     Central Michigan       FS
# 2     43534    6-0     205  1993-06-02             Illinois       SS
# 3     43535    6-1     235  1992-12-22               Temple      MLB
# 4     44174    6-1     236  1993-02-22           Texas Tech      ILB
# ...     ...    ...     ...         ...                  ...      ...
# 2727  33216    6-3     320  06/16/1986      Central Florida        G
# 2728  33184    6-3     265  05/02/1985  Winston-Salem State       DE
# 2729  45651    5-9     198  06/16/1993                 Iowa       WR
# 2730  41284     73     230  1992-10-20                  LSU       RB
# 2731  42849   5-10     205  12/14/1992           Texas Tech       WR
#
#             displayName
# 0          Dean Marlowe
# 1         Kavon Frazier
# 2     Clayton Fejedelem
# 3      Tyler Matakevich
# ...
